# %% [markdown]
# # Description of the code:

# %%
from segmentation import segment_image, init_image, p

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

from joblib import Parallel

from useful_func import *


from skimage.transform import rescale, resize, downscale_local_mean
import skimage
from scipy.ndimage import binary_erosion

from matplotlib.colors import ListedColormap, Normalize


import tifffile as tiff
from tqdm import tqdm

sigma_480 = 198 #m2/mol
sigma_405 = 415 #m2/mol
tau_relax = 0.014

import click

import CSLtools.CSLtools as CSLtools

import incense
from incense import ExperimentLoader

#source: incense github page

def get_mongo_uri():
    in_devcontainer = (
        os.environ.get("TERM_PROGRAM") == "vscode"
        or os.environ.get("HOME") == "/home/vscode"
        or (os.environ.get("PATH") or "").startswith("/home/vscode")
    )
    if in_devcontainer:
        return "mongodb://mongo:27017"
    else:
        return None



loader = ExperimentLoader(
    mongo_uri=get_mongo_uri(), 
    db_name='sacred'
)

#%matplotlib widget

# %%
idi = 40 #623
exp = loader.find_by_id(idi)
video = tiff.imread(exp.artifacts["video.tiff"].file)
save_folder = glob.glob("D:/github/CSL-forge/Experiments/%d_*"%idi)[0]
timing = exp.metrics["Time"]

# %%
video.max()
# Out:
# 85.685

# %%
framerate = 1/(timing[1]-timing[0])

plt.xlabel('time (s)')
plt.ylabel('mean signal')
x = timing
y= np.mean(video[0:], axis = (1,2))
plt.plot(x[y>2], y[y>2], "-o")
plt.figure()

# %%
file = glob.glob(save_folder + "/video.tiff")[0]

FO = init_image(file)
FO.frames = FO.frames/255
p.save_folder= save_folder
watershed_im_mask, FO    = segment_image(FO, contrast = 6, autolevel = 5, dist_max = True, dist_seg=True, disk_size = 1, max_contrast = 3, interact = False, showit= False)  
np.save(save_folder + "/labels.npy", watershed_im_mask)
# Out:
# exception calling callback for <Future at 0x1cf1b288cd0 state=finished returned list>
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 862, in dispatch_one_batch
#     tasks = self._ready_batches.get(block=False)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\queue.py", line 167, in get
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 873, in dispatch_one_batch
#     islice = list(itertools.islice(iterator, big_batch_size))
#   File "d:\github\alienlab\alienlab\fo.py", line 39, in <genexpr>
#     return np.asarray(Parallel(n_jobs=-1, max_nbytes=None)(delayed(task)(skimage.util.img_as_ubyte(self.frames[i]), **kwargs)
# IndexError: index 2050 is out of bounds for axis 0 with size 2050
# exception calling callback for <Future at 0x1cf1b2e2400 state=finished returned list>
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 862, in dispatch_one_batch
#     tasks = self._ready_batches.get(block=False)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\queue.py", line 167, in get
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 873, in dispatch_one_batch
#     islice = list(itertools.islice(iterator, big_batch_size))
#   File "d:\github\alienlab\alienlab\fo.py", line 39, in <genexpr>
#     return np.asarray(Parallel(n_jobs=-1, max_nbytes=None)(delayed(task)(skimage.util.img_as_ubyte(self.frames[i]), **kwargs)
# IndexError: index 2050 is out of bounds for axis 0 with size 2050
# exception calling callback for <Future at 0x1cf1b6ebf10 state=finished returned list>
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 862, in dispatch_one_batch
#     tasks = self._ready_batches.get(block=False)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\queue.py", line 167, in get
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 873, in dispatch_one_batch
#     islice = list(itertools.islice(iterator, big_batch_size))
#   File "d:\github\alienlab\alienlab\fo.py", line 39, in <genexpr>
#     return np.asarray(Parallel(n_jobs=-1, max_nbytes=None)(delayed(task)(skimage.util.img_as_ubyte(self.frames[i]), **kwargs)
# IndexError: index 2050 is out of bounds for axis 0 with size 2050
# --- Computed binary mask in 14.420139 seconds ---
# exception calling callback for <Future at 0x1cf1b6eb4c0 state=finished returned list>
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 862, in dispatch_one_batch
#     tasks = self._ready_batches.get(block=False)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\queue.py", line 167, in get
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\alien\Anaconda3\envs\cslforge\lib\site-packages\joblib\parallel.py", line 873, in dispatch_one_batch
#     islice = list(itertools.islice(iterator, big_batch_size))
#   File "d:\github\alienlab\alienlab\fo.py", line 39, in <genexpr>
#     return np.asarray(Parallel(n_jobs=-1, max_nbytes=None)(delayed(task)(skimage.util.img_as_ubyte(self.frames[i]), **kwargs)
# IndexError: index 2050 is out of bounds for axis 0 with size 2050
# --- Computed binary mask in 15.066410 seconds ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 FO.frames = FO.frames/255
#       5 p.save_folder= save_folder
# ----> 6 watershed_im_mask, FO    = segment_image(FO, contrast = 6, autolevel = 5, dist_max = True, dist_seg=True, disk_size = 1, max_contrast = 3, interact = False, showit= False)
#       7 np.save(save_folder + "/labels.npy", watershed_im_mask)
#
# File D:\github\CSL-forge\CSL-analysis\segmentation.py:107, in segment_image(FO, contrast, autolevel, dist_max, dist_seg, disk_size, max_contrast, interact, showit)
#     104 start_time = time.time()
#     106 #locate the local maxima
# --> 107 local_maxi = alienlab.segment.local_maxima(auto_contrast, max_contrast, p,
#     108                                                  ref_distance = dist_max, mask = mask_intersect, show = showit)
#     109 #perform watershed segmentation
#     110 watershed_im_mask = alienlab.segment.watershed(ref*mask_intersect, mask , local_maxi,
#     111                                                      p, ref_distance = dist_seg, show = True)
#
# File d:\github\alienlab\alienlab\segment.py:41, in local_maxima(im, min_distance, h, ref_distance, mask, show)
#      38 local_maxi = skimage.feature.peak_local_max(im, min_distance=min_distance)
#      40 distance = normalize(ndi.distance_transform_edt(mask))
# ---> 41 dist_local_maxi = skimage.feature.peak_local_max(distance, indices = False, min_distance=min_distance)
#      43 if show == True:
#      44     peaks = np.array([im, im, im])
#
# TypeError: peak_local_max() got an unexpected keyword argument 'indices'

# %%
#parallel fit on each pixel of the mask
tau_lists = Parallel(n_jobs = -1 )(parallel_tau(to_evaluate[start:stop,i], timing[start:stop], sample_rate = framerate) for i in tqdm(range(to_evaluate.shape[1])))

# %%
tau_480 = np.array(tau_lists)
tau_480_map = np.zeros(mask.shape)
tau_480_map[mask] = tau_480


I_480 = 1e6*(1/tau_480 - tau_relax)/sigma_480
I_480_map = np.zeros(mask.shape)
I_480_map[mask] = I_480

np.save(save_folder + "/I_480_map.npy", I_480_map)

plt.rcParams['image.cmap'] = 'viridis'
dd, uu = plot_map(tau_480, tau_480_map, save_folder + "/tau_480_map_B", limits = (0,20))


plt.rcParams['image.cmap'] = 'Blues_r'
I, dis = plot_map(I_480, I_480_map, save_folder + "/I_480_map_B" + extension, limits = (0, 1500))

np.save(save_folder + "/video_2D.npy", video_2D[start:stop])
np.save(save_folder + "/framerate.npy", framerate)

# %%
image = plt.imshow(D_image, cmap = "gray")
plt.axis("off")
divider = make_axes_locatable(plt.gca())
axdef = divider.append_axes("bottom", "5%", pad="3%")
cbar = plt.colorbar(image, cax=axdef, orientation = "horizontal")
plt.xlabel("$grey$ $level$", size = 15)
# Out:
# Text(0.5, 0, '$grey$ $level$')

# %%
loc_im = tau_480_map
loc_im[loc_im==loc_im.max()] = loc_im.min()
image = plt.imshow(loc_im, cmap = "viridis")#[58:177,118:232])
plt.axis("off")
divider = make_axes_locatable(plt.gca())
axdef = divider.append_axes("bottom", "5%", pad="3%")
cbar = plt.colorbar(image, cax=axdef, orientation = "horizontal")
plt.xlabel(r"$\tau$ (s)", size = 15)
plt.savefig('results/tau_map' + extension)

# %%
loc_im = I_480_map
loc_im[loc_im==loc_im.max()] = loc_im.min()
image = plt.imshow(loc_im, cmap = "Blues_r")#[58:177,118:232])
plt.axis("off")
divider = make_axes_locatable(plt.gca())
axdef = divider.append_axes("bottom", "5%", pad="3%")
cbar = plt.colorbar(image, cax=axdef, orientation = "horizontal")
plt.xlabel(r"$light$ $intensity$ ($\mathrm{\mu E \cdot m^2 \cdot s^{-1}}$)", size = 15)
plt.tight_layout()
plt.savefig('results/intensity_map' + extension, bbox_inches = 'tight')

# %%
fig, ax = CSLtools.set_figure("%d", "%d")
clean = [231, 232, 234, 239, 240, 242, 244, 245, 246, 247, 248,249]
dirty = [235, 236, 237, 238]
for idi in clean + dirty:#[218, 219, 220, 221, 222]:
    exp = loader.find_by_id(idi)
    x = exp.metrics['Time']
    y = exp.metrics['Fluorescence'].values
    conv = np.mean(y[-10:])
    #if idi in clean:
    #    plt.plot(x, (y-conv)/(y[0]-conv))
    params = simple_tau(y, x, sample_rate = framerate)
    
    intensity = exp.config.arduino_LED.blue_param.analog_value
    ax.plot(intensity*100/255, 1e6/(sigma_480*params[1]), '.k')
plt.ylabel(r"$light$ $intensity$ ($\mathrm{\mu E \cdot m^2 \cdot s^{-1}}$)", size = 15)
plt.xlabel("PWM duty cycle (%)")
plt.savefig('results/PWM_dronpa2_calib_UC2' + extension)

# %%
fig, ax = CSLtools.set_figure("%d", "%0.1f")
clean = [242, 244, 248,249]

get_color = CSLtools.val_cmap("gray", [0, 350])

for idi in clean:#[218, 219, 220, 221, 222]:
    
    exp = loader.find_by_id(idi)
    x = exp.metrics['Time']
    y = exp.metrics['Fluorescence'].values
    conv = np.mean(y[-10:])
    params = simple_tau(y, x, sample_rate = framerate)
    
    intensity = exp.config.arduino_LED.blue_param.analog_value
    plt.plot(x, (y-conv)/(y[0]-conv), color = get_color(intensity))

    print(intensity, idi)
plt.ylabel(r"$normalized$ $fluorescence$ (a.u)", size = 15)
plt.xlabel("$time$ (s)", size = 15)
plt.savefig('results/curves_dronpa2_calib_UC2' + extension)
# Out:
# 200 242
# 250 244
# 150 248
# 100 249
